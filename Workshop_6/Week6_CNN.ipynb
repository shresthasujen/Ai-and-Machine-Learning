# %% [markdown]
# ## **Simple CNN Implemented using Keras.**

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image

# %% [markdown]
# ## **Task 1: Data Understanding and Visualization:**

# %%
import zipfile

# %%
file_path = '/content/FruitinAmazon.zip'

# %%
with zipfile.ZipFile(file_path, 'r') as zip_ref:
    zip_ref.extractall('/content/FruitinAmazon')

# %%
# Define paths
train_dir = '/content/FruitinAmazon/FruitinAmazon/train'
test_dir = '/content/FruitinAmazon/FruitinAmazon/test'

# %% [markdown]
# 1. Load and visualize images from a dataset stored in directories, where each subdirec-
# tory represents a class. You are expected to write a code:
#
# *   Get the list of class directories from the train folder.
# *   Select one image randomly from each class.
# *   Display the images in a grid format with two rows using matplotlib.

# %%
import os
import random
import matplotlib.pyplot as plt

def visualize_data(train_data_dir):
    # Get the list of class directories
    class_dirs = [d for d in os.listdir(train_data_dir) ]
    print(class_dirs)

    # Select one image randomly from each class
    images = []
    labels = []
    for class_dir in class_dirs:
        class_path = os.path.join(train_data_dir, class_dir)
        image_files = [f for f in os.listdir(class_path) if os.path.isfile(os.path.join(class_path, f))]
        random_image_file = random.choice(image_files)
        image_path = os.path.join(class_path, random_image_file)
        images.append(plt.imread(image_path))
        labels.append(class_dir)

    # Display the images in a grid format with two rows using matplotlib
    fig, axes = plt.subplots(2, len(class_dirs) // 2, figsize=(12, 6))
    for i, (image, label) in enumerate(zip(images, labels)):
        row = i // (len(class_dirs) // 2)
        col = i % (len(class_dirs) // 2)
        axes[row, col].imshow(image)
        axes[row, col].set_title(label)
        axes[row, col].axis('off')

    plt.tight_layout()
    plt.show()

# %%
visualize_data(train_dir)
# Out:
# ['pupunha', 'tucuma', 'cupuacu', 'graviola', 'guarana', 'acai']

# %% [markdown]
# 2. Check for Corrupted Image: Write a script that verifies whether the image in the train
# directory are valid. If any corrupted images are found, the script must remove the image from
# the directory and print the message which image have been removed, if none found print ”No Corrupted Images Found.”
#
# Hint:
# - Iterate through each class subdirectory and check if each image is valid.
# - Use the Image.open() function to attempt to load each image.
# - If the image is corrupted i.e. raises an IOError or SyntaxError, remove the image from the directory and print f"Removed corrupted image: {image_path}".
# - Maintain a list of all corrupted image paths for reporting.
#
# Expected Output: No corrupted images found.

# %%
import os
from PIL import Image

def check_and_remove_corrupted_images(train_folder):
    corrupted_images = []
    for class_dir in os.listdir(train_folder):
        class_path = os.path.join(train_folder, class_dir)
        if os.path.isdir(class_path):
            for image_file in os.listdir(class_path):
                image_path = os.path.join(class_path, image_file)
                try:
                    with Image.open(image_path) as img:
                        # Verify image format
                        img.verify()
                except (IOError, SyntaxError) as e:
                    corrupted_images.append(image_path)
                    os.remove(image_path)
                    print(f"Removed corrupted image: {image_path}")

    if not corrupted_images:
        print("No corrupted images found.")
    else:
        print(f"Total corrupted images removed: {len(corrupted_images)}")


check_and_remove_corrupted_images(train_dir)
# Out:
# No corrupted images found.

# %%
import tensorflow as tf
# Define image size and batch size
img_height = 128
img_width = 128
batch_size = 32
validation_split = 0.2  # 80% training, 20% validation

# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255)  # Normalize pixel values to [0, 1]

# Create training dataset with normalization
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)

# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))

# Create validation dataset with normalization
val_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)

# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %%
model = tf.keras.models.Sequential([
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(img_height, img_width, 3)),
      tf.keras.layers.MaxPooling2D((2, 2)),
      tf.keras.layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
      tf.keras.layers.MaxPooling2D((2, 2)),
      tf.keras.layers.Flatten(),
      tf.keras.layers.Dense(64, activation='relu'),
      tf.keras.layers.Dense(128, activation='relu'),
      tf.keras.layers.Dense(6, activation='softmax') # 6 for 6 classes of fruits
])
model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer='adam',
                loss='sparse_categorical_crossentropy',
                metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_4 (Conv2D)                    │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 64, 64, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 32, 32, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 64)                  │       2,097,216 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,116,454 (8.07 MB)
#  Trainable params: 2,116,454 (8.07 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# Define callbacks
callbacks = [
    ModelCheckpoint('best_model.h5', monitor='val_loss', save_best_only=True, mode='min', verbose=1),
    EarlyStopping(monitor='val_loss', patience=10, verbose=1, restore_best_weights=True)
]

# Train the model
history = model.fit(
    train_ds,
    epochs=250,
    batch_size=16,
    validation_data=val_ds,  # Use val_ds for validation
    callbacks=callbacks  # Use callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.1250 - loss: 1.9497
# Epoch 1: val_loss improved from inf to 1.51959, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 586ms/step - accuracy: 0.1250 - loss: 1.9648 - val_accuracy: 0.7778 - val_loss: 1.5196
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.1991 - loss: 1.7921
# Epoch 2: val_loss did not improve from 1.51959
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 461ms/step - accuracy: 0.2049 - loss: 1.7822 - val_accuracy: 0.2778 - val_loss: 1.6176
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.3935 - loss: 1.5951
# Epoch 3: val_loss did not improve from 1.51959
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 434ms/step - accuracy: 0.4028 - loss: 1.5897 - val_accuracy: 0.1111 - val_loss: 1.6299
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.4850 - loss: 1.3626
# Epoch 4: val_loss did not improve from 1.51959
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 517ms/step - accuracy: 0.4852 - loss: 1.3558 - val_accuracy: 0.2778 - val_loss: 1.5947
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.5758 - loss: 1.0821
# Epoch 5: val_loss improved from 1.51959 to 0.81946, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 475ms/step - accuracy: 0.5707 - loss: 1.0896 - val_accuracy: 0.7778 - val_loss: 0.8195
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.7257 - loss: 0.9015
# Epoch 6: val_loss improved from 0.81946 to 0.73063, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 474ms/step - accuracy: 0.7214 - loss: 0.9128 - val_accuracy: 0.8333 - val_loss: 0.7306
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 0.8113 - loss: 0.7276
# Epoch 7: val_loss did not improve from 0.73063
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 431ms/step - accuracy: 0.8030 - loss: 0.7289 - val_accuracy: 0.6667 - val_loss: 1.1983
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.8808 - loss: 0.5801
# Epoch 8: val_loss did not improve from 0.73063
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 426ms/step - accuracy: 0.8759 - loss: 0.5874 - val_accuracy: 0.6667 - val_loss: 1.0297
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 608ms/step - accuracy: 0.9404 - loss: 0.3955
# Epoch 9: val_loss improved from 0.73063 to 0.59547, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 814ms/step - accuracy: 0.9379 - loss: 0.3947 - val_accuracy: 0.8889 - val_loss: 0.5955
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.9404 - loss: 0.2890
# Epoch 10: val_loss improved from 0.59547 to 0.36866, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - accuracy: 0.9379 - loss: 0.2913 - val_accuracy: 0.8889 - val_loss: 0.3687
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.9196 - loss: 0.2100
# Epoch 11: val_loss did not improve from 0.36866
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 443ms/step - accuracy: 0.9223 - loss: 0.2098 - val_accuracy: 0.8333 - val_loss: 0.5429
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step - accuracy: 1.0000 - loss: 0.1012
# Epoch 12: val_loss did not improve from 0.36866
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 448ms/step - accuracy: 1.0000 - loss: 0.1011 - val_accuracy: 0.7778 - val_loss: 0.7867
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9595 - loss: 0.1350
# Epoch 13: val_loss did not improve from 0.36866
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 450ms/step - accuracy: 0.9627 - loss: 0.1319 - val_accuracy: 0.8333 - val_loss: 0.3738
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step - accuracy: 1.0000 - loss: 0.0364
# Epoch 14: val_loss improved from 0.36866 to 0.10760, saving model to best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 480ms/step - accuracy: 1.0000 - loss: 0.0367 - val_accuracy: 1.0000 - val_loss: 0.1076
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 540ms/step - accuracy: 1.0000 - loss: 0.0389
# Epoch 15: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 719ms/step - accuracy: 1.0000 - loss: 0.0394 - val_accuracy: 0.9444 - val_loss: 0.1682
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step - accuracy: 1.0000 - loss: 0.0275
# Epoch 16: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 560ms/step - accuracy: 1.0000 - loss: 0.0282 - val_accuracy: 0.8889 - val_loss: 0.2346
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 1.0000 - loss: 0.0118
# Epoch 17: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 441ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.8333 - val_loss: 0.2730
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - accuracy: 1.0000 - loss: 0.0065
# Epoch 18: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 1.0000 - loss: 0.0066 - val_accuracy: 0.8333 - val_loss: 0.3133
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 1.0000 - loss: 0.0054
# Epoch 19: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 421ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.8333 - val_loss: 0.3607
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 1.0000 - loss: 0.0047
# Epoch 20: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 424ms/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.8333 - val_loss: 0.4131
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 1.0000 - loss: 0.0030
# Epoch 21: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 523ms/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.8333 - val_loss: 0.4186
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 582ms/step - accuracy: 1.0000 - loss: 0.0023
# Epoch 22: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 756ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.8333 - val_loss: 0.3740
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 1.0000 - loss: 0.0017
# Epoch 23: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 434ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.8333 - val_loss: 0.3265
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 1.0000 - loss: 0.0014
# Epoch 24: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 443ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.8333 - val_loss: 0.2921
# Epoch 24: early stopping
# Restoring model weights from the end of the best epoch: 14.

# %%
# Create test dataset with normalization
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False  # Important to keep test data in original order
)

# Apply the normalization (Rescaling) to the test dataset
test_ds = test_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 30 files belonging to 6 classes.

# %%
# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(test_ds)

print('Test Loss:', loss)
print('Test Accuracy:', accuracy)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step - accuracy: 0.7667 - loss: 0.5885
# Test Loss: 0.5885375738143921
# Test Accuracy: 0.7666666507720947

# %%
# Plot training and validation accuracy
plt.figure(figsize=(7, 7))
# Accuracy plot

plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
# Loss plot
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Task - 1:**

# %% [markdown]
# Repeat all the task from worksheet - 5 but, try to improve the model from last week with same dataset.
#
# Use Data Augmentation to increase the number of training image.
# Use deeper model with BN and DropOut layer as presented above.
# Understand the Model Summary and Training Behavior.

# %%
data_augmentation_layers = [
  layers.RandomFlip("horizontal"),
  layers.RandomRotation(0.1),
]

def data_augmentation(images):
  for layer in data_augmentation_layers:
    images = layer(images)
  return images

# %%
# Define an improved CNN model with Batch Normalization and Dropout
modelcnn2 = keras.Sequential([

    # Data augmentation applied using Lambda layer
    layers.Lambda(data_augmentation, input_shape=(128,128, 3)),

    # Rescaling layer to normalize pixel values
    layers.Rescaling(1./255),

    layers.Conv2D(32, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.2),

    layers.Conv2D(64, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.3),

    layers.Conv2D(128, (3, 3), activation="relu", padding="same"),
    layers.BatchNormalization(),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.4),

    layers.Flatten(),
    layers.Dense(256, activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),
    layers.Dense(6, activation="softmax")
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/lambda_layer.py:65: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
modelcnn2.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
# Display model summary
modelcnn2.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lambda (Lambda)                      │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling_1 (Rescaling)              │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization                  │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 32, 32, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 32, 32, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_8 (MaxPooling2D)       │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 16, 16, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 32768)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 256)                 │       8,388,864 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_3                │ (None, 256)                 │           1,024 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 6)                   │           1,542 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,485,574 (32.37 MB)
#  Trainable params: 8,484,614 (32.37 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
# Train the model
cnn_history = modelcnn2.fit(
    train_ds,  # Training dataset
    validation_data=val_ds,  # Validation dataset
    epochs=250,  # Number of epochs
    batch_size=32,  # Batch size
    callbacks=callbacks  # Callbacks for early stopping and saving the best model
    # jit_compile =False # Remove this line - it's not a valid argument for model.fit
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2541 - loss: 3.1749
# Epoch 1: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.2600 - loss: 3.1644 - val_accuracy: 0.0000e+00 - val_loss: 1.7923
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4253 - loss: 1.5807
# Epoch 2: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4232 - loss: 1.5825 - val_accuracy: 0.0000e+00 - val_loss: 1.8430
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4693 - loss: 1.3697
# Epoch 3: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.4735 - loss: 1.3891 - val_accuracy: 0.0000e+00 - val_loss: 1.7946
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5156 - loss: 1.3892
# Epoch 4: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.5117 - loss: 1.3996 - val_accuracy: 0.8333 - val_loss: 1.6792
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6458 - loss: 0.9259
# Epoch 5: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.6406 - loss: 0.9342 - val_accuracy: 0.8333 - val_loss: 1.5922
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7269 - loss: 0.8823
# Epoch 6: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7153 - loss: 0.9083 - val_accuracy: 0.8333 - val_loss: 1.5218
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7008 - loss: 0.9203
# Epoch 7: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.6957 - loss: 0.9328 - val_accuracy: 0.8333 - val_loss: 1.4951
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7865 - loss: 0.6852
# Epoch 8: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7773 - loss: 0.6934 - val_accuracy: 0.8333 - val_loss: 1.4496
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7396 - loss: 0.8156
# Epoch 9: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.7422 - loss: 0.8049 - val_accuracy: 0.1667 - val_loss: 1.4488
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8461 - loss: 0.4046
# Epoch 10: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.8394 - loss: 0.4227 - val_accuracy: 0.1667 - val_loss: 1.4483
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7899 - loss: 0.6071
# Epoch 11: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 1s/step - accuracy: 0.7904 - loss: 0.6094 - val_accuracy: 0.1667 - val_loss: 1.4928
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7650 - loss: 0.5821
# Epoch 12: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 2s/step - accuracy: 0.7648 - loss: 0.5970 - val_accuracy: 0.1667 - val_loss: 1.5227
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8507 - loss: 0.5237
# Epoch 13: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8464 - loss: 0.5417 - val_accuracy: 0.1667 - val_loss: 1.5547
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8102 - loss: 0.4739
# Epoch 14: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.8090 - loss: 0.4792 - val_accuracy: 0.1667 - val_loss: 1.6204
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8715 - loss: 0.3881
# Epoch 15: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 11s 2s/step - accuracy: 0.8620 - loss: 0.4098 - val_accuracy: 0.1667 - val_loss: 1.6905
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7784 - loss: 0.5768
# Epoch 16: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.7886 - loss: 0.5512 - val_accuracy: 0.1667 - val_loss: 1.7549
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9051 - loss: 0.3226
# Epoch 17: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9045 - loss: 0.3216 - val_accuracy: 0.1667 - val_loss: 1.8423
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9005 - loss: 0.3277
# Epoch 18: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 10s 2s/step - accuracy: 0.8976 - loss: 0.3377 - val_accuracy: 0.1667 - val_loss: 1.9057
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8802 - loss: 0.4027
# Epoch 19: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.8789 - loss: 0.4042 - val_accuracy: 0.1667 - val_loss: 1.9750
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9462 - loss: 0.2486
# Epoch 20: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 6s 1s/step - accuracy: 0.9388 - loss: 0.2648 - val_accuracy: 0.1667 - val_loss: 2.0613
# Epoch 20: early stopping
# Restoring model weights from the end of the best epoch: 10.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelcnn2.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.1667 - loss: 1.8853
#
#
# Test Loss: 1.8853, Test Accuracy: 0.1667

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(cnn_history.history['accuracy'], label='Training Accuracy')
plt.plot(cnn_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(cnn_history.history['loss'], label='Training Loss')
plt.plot(cnn_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **MobilenetV2**

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# Define input shape
input_shape = (128, 128, 3)
base_model = MobileNetV2(input_shape=input_shape, include_top=False, weights='imagenet')

# Freeze the base model
base_model.trainable = False

# Add custom layers on top
inputs = Input(shape=input_shape)
x = base_model(inputs, training=False)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
outputs = Dense(6, activation='softmax')(x)  # Adjust to your number of classes

# Create the model
modelnetv2 = Model(inputs, outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_128_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.optimizers import Adam

modelnetv2.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
vnet2_history = modelnetv2.fit(
    train_ds,
    validation_data=val_ds,
    epochs=250,
    batch_size=16,
    callbacks=callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - accuracy: 0.2998 - loss: 1.9732
# Epoch 1: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 9s 1s/step - accuracy: 0.3012 - loss: 1.9714 - val_accuracy: 0.8333 - val_loss: 0.8890
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 0.7911 - loss: 0.7967
# Epoch 2: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 401ms/step - accuracy: 0.7843 - loss: 0.7994 - val_accuracy: 0.9444 - val_loss: 0.4739
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.8704 - loss: 0.4883
# Epoch 3: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 360ms/step - accuracy: 0.8681 - loss: 0.4837 - val_accuracy: 0.9444 - val_loss: 0.3783
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step - accuracy: 0.9803 - loss: 0.2296
# Epoch 4: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 353ms/step - accuracy: 0.9783 - loss: 0.2312 - val_accuracy: 0.9444 - val_loss: 0.3638
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9497 - loss: 0.1683
# Epoch 5: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 752ms/step - accuracy: 0.9518 - loss: 0.1640 - val_accuracy: 0.9444 - val_loss: 0.3039
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step - accuracy: 1.0000 - loss: 0.0512
# Epoch 6: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 403ms/step - accuracy: 1.0000 - loss: 0.0522 - val_accuracy: 0.9444 - val_loss: 0.2768
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 1.0000 - loss: 0.0456
# Epoch 7: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step - accuracy: 1.0000 - loss: 0.0466 - val_accuracy: 0.9444 - val_loss: 0.2506
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step - accuracy: 1.0000 - loss: 0.0420
# Epoch 8: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 439ms/step - accuracy: 1.0000 - loss: 0.0400 - val_accuracy: 0.9444 - val_loss: 0.2240
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - accuracy: 1.0000 - loss: 0.0286
# Epoch 9: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 342ms/step - accuracy: 1.0000 - loss: 0.0278 - val_accuracy: 0.9444 - val_loss: 0.2209
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 10: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.9444 - val_loss: 0.2327
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - accuracy: 1.0000 - loss: 0.0215
# Epoch 11: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 378ms/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9444 - val_loss: 0.2538
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 1.0000 - loss: 0.0138
# Epoch 12: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 327ms/step - accuracy: 1.0000 - loss: 0.0135 - val_accuracy: 0.9444 - val_loss: 0.2778
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - accuracy: 1.0000 - loss: 0.0080
# Epoch 13: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 614ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9444 - val_loss: 0.3030
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 1.0000 - loss: 0.0088
# Epoch 14: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 538ms/step - accuracy: 1.0000 - loss: 0.0086 - val_accuracy: 0.9444 - val_loss: 0.3166
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - accuracy: 1.0000 - loss: 0.0069
# Epoch 15: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 334ms/step - accuracy: 1.0000 - loss: 0.0067 - val_accuracy: 0.9444 - val_loss: 0.3217
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step - accuracy: 1.0000 - loss: 0.0044
# Epoch 16: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - accuracy: 1.0000 - loss: 0.0043 - val_accuracy: 0.9444 - val_loss: 0.3229
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - accuracy: 1.0000 - loss: 0.0037
# Epoch 17: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - accuracy: 1.0000 - loss: 0.0038 - val_accuracy: 0.9444 - val_loss: 0.3228
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step - accuracy: 1.0000 - loss: 0.0076
# Epoch 18: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step - accuracy: 1.0000 - loss: 0.0078 - val_accuracy: 0.9444 - val_loss: 0.3143
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step - accuracy: 1.0000 - loss: 0.0024
# Epoch 19: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 328ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9444 - val_loss: 0.3058
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 9.

# %%
modelnetv2.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 128, 128, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ mobilenetv2_1.00_128 (Functional)    │ (None, 4, 4, 1280)          │       2,257,984 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ global_average_pooling2d             │ (None, 1280)                │               0 │
# │ (GlobalAveragePooling2D)             │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 1280)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 128)                 │         163,968 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 6)                   │             774 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,752,212 (10.50 MB)
#  Trainable params: 164,742 (643.52 KB)
#  Non-trainable params: 2,257,984 (8.61 MB)
#  Optimizer params: 329,486 (1.26 MB)

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelnetv2.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7333 - loss: 0.7248
#
#
# Test Loss: 0.7248, Test Accuracy: 0.7333

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(vnet2_history.history['accuracy'], label='Training Accuracy')
plt.plot(vnet2_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(vnet2_history.history['loss'], label='Training Loss')
plt.plot(vnet2_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **VGG16**

# %%
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, Input

# %%
# Load the VGG16 model pre-trained on ImageNet, without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(128,128, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for layer in base_model.layers:
  layer.trainable = False

# %%
# Add custom layers on top of the pre-trained model
x = base_model.output
x = GlobalAveragePooling2D()(x) # Reduces dimensions (height, width) to a single vector per image
x = Dense(1024, activation='relu')(x) # Fully connected layer with 1024 neurons
x = Dense(10, activation='softmax')(x) # Output layer for 10 classes (with softmax for multi-class classification)

# %%
from tensorflow.keras.models import Model
# Create the final model
modelvgg16 = Model(inputs=base_model.input, outputs=x)

# %%
from tensorflow.keras.optimizers import Adam
# Compile the model
modelvgg16.compile(optimizer=Adam(), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
vgg_history = modelvgg16.fit(
    train_ds,
    validation_data=val_ds,
    epochs=250,
    batch_size=32,
    callbacks=callbacks
)
# Out:
# Epoch 1/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.0197 - loss: 2.4472
# Epoch 1: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 7s/step - accuracy: 0.0217 - loss: 2.4185 - val_accuracy: 0.5000 - val_loss: 1.7100
# Epoch 2/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4850 - loss: 1.5816
# Epoch 2: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 37s 6s/step - accuracy: 0.4852 - loss: 1.5797 - val_accuracy: 0.3333 - val_loss: 1.6758
# Epoch 3/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4983 - loss: 1.3782
# Epoch 3: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.5091 - loss: 1.3709 - val_accuracy: 0.7222 - val_loss: 1.1446
# Epoch 4/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8362 - loss: 1.1089
# Epoch 4: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 0.8286 - loss: 1.1076 - val_accuracy: 0.7778 - val_loss: 0.7724
# Epoch 5/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.6638 - loss: 1.0129
# Epoch 5: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 0.6714 - loss: 1.0085 - val_accuracy: 0.8333 - val_loss: 0.8854
# Epoch 6/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8605 - loss: 0.8240
# Epoch 6: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 7s/step - accuracy: 0.8572 - loss: 0.8249 - val_accuracy: 0.6111 - val_loss: 1.0836
# Epoch 7/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8814 - loss: 0.6858
# Epoch 7: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.8728 - loss: 0.6956 - val_accuracy: 0.7222 - val_loss: 1.0058
# Epoch 8/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9306 - loss: 0.6174
# Epoch 8: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 0.9271 - loss: 0.6177 - val_accuracy: 0.7778 - val_loss: 0.7427
# Epoch 9/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9201 - loss: 0.5553
# Epoch 9: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 0.9193 - loss: 0.5561 - val_accuracy: 0.7778 - val_loss: 0.6149
# Epoch 10/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9294 - loss: 0.4816
# Epoch 10: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9332 - loss: 0.4787 - val_accuracy: 0.7222 - val_loss: 0.6395
# Epoch 11/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9051 - loss: 0.4575
# Epoch 11: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 5s/step - accuracy: 0.9045 - loss: 0.4565 - val_accuracy: 0.6667 - val_loss: 0.7872
# Epoch 12/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.8738 - loss: 0.4537
# Epoch 12: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 0.8811 - loss: 0.4440 - val_accuracy: 0.7222 - val_loss: 0.7532
# Epoch 13/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9398 - loss: 0.3537
# Epoch 13: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 0.9410 - loss: 0.3506 - val_accuracy: 0.7778 - val_loss: 0.6479
# Epoch 14/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9601 - loss: 0.2931
# Epoch 14: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 0.9596 - loss: 0.2932 - val_accuracy: 0.8333 - val_loss: 0.5670
# Epoch 15/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.9855 - loss: 0.2394
# Epoch 15: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 0.9822 - loss: 0.2467 - val_accuracy: 0.8889 - val_loss: 0.5238
# Epoch 16/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.2146
# Epoch 16: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.2181 - val_accuracy: 0.9444 - val_loss: 0.4732
# Epoch 17/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.2005
# Epoch 17: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 7s/step - accuracy: 1.0000 - loss: 0.2001 - val_accuracy: 0.9444 - val_loss: 0.4532
# Epoch 18/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.1867
# Epoch 18: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.1846 - val_accuracy: 0.9444 - val_loss: 0.3927
# Epoch 19/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1557
# Epoch 19: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.1562 - val_accuracy: 0.9444 - val_loss: 0.3873
# Epoch 20/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1499
# Epoch 20: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.1479 - val_accuracy: 0.9444 - val_loss: 0.4390
# Epoch 21/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.1179
# Epoch 21: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.1213 - val_accuracy: 0.8889 - val_loss: 0.4524
# Epoch 22/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.1118
# Epoch 22: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.1139 - val_accuracy: 0.8889 - val_loss: 0.4393
# Epoch 23/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.1071
# Epoch 23: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 1.0000 - loss: 0.1069 - val_accuracy: 0.8889 - val_loss: 0.3884
# Epoch 24/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0943
# Epoch 24: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0948 - val_accuracy: 0.8889 - val_loss: 0.3515
# Epoch 25/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0900
# Epoch 25: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.0896 - val_accuracy: 0.8889 - val_loss: 0.3500
# Epoch 26/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0772
# Epoch 26: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0781 - val_accuracy: 0.9444 - val_loss: 0.3350
# Epoch 27/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0753
# Epoch 27: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.0751 - val_accuracy: 0.9444 - val_loss: 0.3018
# Epoch 28/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0655
# Epoch 28: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0662 - val_accuracy: 0.9444 - val_loss: 0.3016
# Epoch 29/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0595
# Epoch 29: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.0605 - val_accuracy: 0.9444 - val_loss: 0.3210
# Epoch 30/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0571
# Epoch 30: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.0572 - val_accuracy: 0.8889 - val_loss: 0.3520
# Epoch 31/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0530
# Epoch 31: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 18s 6s/step - accuracy: 1.0000 - loss: 0.0533 - val_accuracy: 0.8889 - val_loss: 0.3725
# Epoch 32/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0509
# Epoch 32: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.0516 - val_accuracy: 0.8889 - val_loss: 0.3603
# Epoch 33/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0486
# Epoch 33: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 20s 6s/step - accuracy: 1.0000 - loss: 0.0485 - val_accuracy: 0.9444 - val_loss: 0.3043
# Epoch 34/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0425
# Epoch 34: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.0429 - val_accuracy: 0.9444 - val_loss: 0.2837
# Epoch 35/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0411
# Epoch 35: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 23s 6s/step - accuracy: 1.0000 - loss: 0.0415 - val_accuracy: 0.9444 - val_loss: 0.2849
# Epoch 36/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0429
# Epoch 36: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 7s/step - accuracy: 1.0000 - loss: 0.0423 - val_accuracy: 0.8889 - val_loss: 0.3100
# Epoch 37/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0381
# Epoch 37: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 5s/step - accuracy: 1.0000 - loss: 0.0379 - val_accuracy: 0.8889 - val_loss: 0.3468
# Epoch 38/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0395
# Epoch 38: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 21s 6s/step - accuracy: 1.0000 - loss: 0.0387 - val_accuracy: 0.8889 - val_loss: 0.3607
# Epoch 39/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0349
# Epoch 39: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.0349 - val_accuracy: 0.8889 - val_loss: 0.3522
# Epoch 40/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0382
# Epoch 40: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 19s 6s/step - accuracy: 1.0000 - loss: 0.0368 - val_accuracy: 0.8889 - val_loss: 0.3242
# Epoch 41/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0325
# Epoch 41: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.0319 - val_accuracy: 0.8889 - val_loss: 0.3052
# Epoch 42/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 1.0000 - loss: 0.0303
# Epoch 42: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 22s 6s/step - accuracy: 1.0000 - loss: 0.0298 - val_accuracy: 0.8889 - val_loss: 0.2996
# Epoch 43/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0259
# Epoch 43: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.0262 - val_accuracy: 0.8889 - val_loss: 0.2972
# Epoch 44/250
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 1.0000 - loss: 0.0240
# Epoch 44: val_loss did not improve from 0.10760
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 17s 6s/step - accuracy: 1.0000 - loss: 0.0244 - val_accuracy: 0.8889 - val_loss: 0.3005
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 34.

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,              # No shuffling for consistent evaluation
)

# Apply the same normalization as train/val
test_ds = test_ds.map(lambda x, y: (rescale(x), y))

# Evaluate the model on the test dataset
test_loss, test_accuracy = modelvgg16.evaluate(test_ds)
print(f"\n\nTest Loss: {test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")
# Out:
# Found 30 files belonging to 6 classes.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 7s 7s/step - accuracy: 0.5333 - loss: 1.3911
#
#
# Test Loss: 1.3911, Test Accuracy: 0.5333

# %%
# Plot training and validation accuracy
plt.figure(figsize=(12, 12))

# Accuracy plot
plt.subplot(2, 1, 1)
plt.plot(vnet2_history.history['accuracy'], label='Training Accuracy')
plt.plot(vnet2_history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Loss plot
plt.subplot(2, 1, 2)
plt.plot(vnet2_history.history['loss'], label='Training Loss')
plt.plot(vnet2_history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
